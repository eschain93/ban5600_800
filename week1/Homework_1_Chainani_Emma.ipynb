# %% [markdown]
# <a href="https://colab.research.google.com/github/eschain93/ban5600_800/blob/main/week1/Homework_1_Chainani_Emma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: Intro Video Reflection - 5 Key Learning Points, Overall Impression, and Constructive Feedback
#
# ### A. 5 Key Learning Points
#
# 1.   Python requires direct guidance in order to perform a task. For example, importing the math library is essential to use the (exp) function.
# 2.   The (print) function is useful not only to show the final result, but even to identify variable types when needed.
# 3.   Comments are useful to help define what your code is doing. It's good for keeping track for homework and on larger programs so all developers understand what the code does.
# 4.   You cannot add a string and an integer, an error will occur. In order to do this, you must convert the integer to a string.
# 5.   Errors are ok and are part of the learning experience.
#
# ### B. Overall Impression
# My overall impression so far is I'm excited to dive in and use Python on a deeper level. I use it in my career and on the side for data visualation side projects as a hobby. I enjoy the simplicity of it and the multitude of libraries available, and learning new ways to run the code. I enjoy the simplicity of the Colab Google notebook. I do have experience working in Spyder and installing libraries via Anaconda. So this is a nice change of pace and allows me to get familiar with new environments.
#
# ### C. Constructive Feedback
# I have no constructive feedback to share. The kick off office hour was helpful in understanding the expectations of this course.

# %% [markdown]
# ## Part 2: Survey
#
# The survey linked in homework 1 has been submitted using the email address emmachainani@gmail.com.

# %% [markdown]
# ## Part 3: Install VS Code & Python
#
# Both Python and VS code were installed on my machine prior to this course. In this video, I will run code that shows the version of Python that is installed.

# %% [markdown]
# ## Part 4: Python Homework

# %%
# Problem 1, Calcuate exp (5)

import math
print(math.exp(5))
# Out:
# 148.4131591025766

# %%
# Problem 2, Calculate exp(-5)

import math
print(math.exp(-5))
# Out:
# 0.006737946999085467

# %%
# Problem 3, Calculate √225

import math
print(math.sqrt(225))
# Out:
# 15.0

# %%
# Problem 4, Calcuate sin (0.523599)

import math
print(math.sin(0.523599))
# Out:
# 0.5000001943375613

# %%
# Problem 5, Ask a user to enter a number.
# After user enters number, screen prints result by using the following equation:
# 2^𝑥 + 2𝑥^3 + 5𝑥^x

x = int(input("Enter a number: "))
answer = 2**x + 2*(x**3) + 5*(x**x)
print("The answer is ", answer)
# Out:
# Enter a number: 2
# The answer is  40

# %%
# Problem 5(a) Write code which asks user to enter two numbers. And it multiplies these numbers and prints the result.

num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
print(num1*num2)
# Out:
# Enter a number: 250
# Enter a number: 1400
# 350000
